# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sinasc = pd.read_csv('SINASC_RO_2019.csv')

# %% [markdown]
# # Módulo 06 Tarefa 2

# %%
sinasc.head(2)
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE       ESCMAE  \
# 0       1  2679477.0      110001        1        19        5.0  8 a 11 anos
# 1       1  2679477.0      110001        1        29        2.0  8 a 11 anos
#
#    CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK CONTADOR munResStatus  \
# 0         NaN         0.0         0.0  ...           5        1        ATIVO
# 1    999992.0         1.0         0.0  ...           5        2        ATIVO
#
#   munResTipo             munResNome  munResUf  munResLat munResLon  munResAlt  \
# 0      MUNIC  Alta Floresta D'Oeste  Rondônia  -11.93554 -61.99982      338.0
# 1      MUNIC  Alta Floresta D'Oeste  Rondônia  -11.93554 -61.99982      338.0
#
#    munResArea
# 0    7067.025
# 1    7067.025
#
# [2 rows x 69 columns]

# %%
sinasc.columns
# Out:
# Index(['ORIGEM', 'CODESTAB', 'CODMUNNASC', 'LOCNASC', 'IDADEMAE', 'ESTCIVMAE',
#        'ESCMAE', 'CODOCUPMAE', 'QTDFILVIVO', 'QTDFILMORT', 'CODMUNRES',
#        'GESTACAO', 'GRAVIDEZ', 'PARTO', 'CONSULTAS', 'DTNASC', 'HORANASC',
#        'SEXO', 'APGAR1', 'APGAR5', 'RACACOR', 'PESO', 'IDANOMAL', 'DTCADASTRO',
#        'CODANOMAL', 'NUMEROLOTE', 'VERSAOSIST', 'DTRECEBIM', 'DIFDATA',
#        'DTRECORIGA', 'NATURALMAE', 'CODMUNNATU', 'CODUFNATU', 'ESCMAE2010',
#        'SERIESCMAE', 'DTNASCMAE', 'RACACORMAE', 'QTDGESTANT', 'QTDPARTNOR',
#        'QTDPARTCES', 'IDADEPAI', 'DTULTMENST', 'SEMAGESTAC', 'TPMETESTIM',
#        'CONSPRENAT', 'MESPRENAT', 'TPAPRESENT', 'STTRABPART', 'STCESPARTO',
#        'TPNASCASSI', 'TPFUNCRESP', 'TPDOCRESP', 'DTDECLARAC', 'ESCMAEAGR1',
#        'STDNEPIDEM', 'STDNNOVA', 'CODPAISRES', 'TPROBSON', 'PARIDADE',
#        'KOTELCHUCK', 'CONTADOR', 'munResStatus', 'munResTipo', 'munResNome',
# ...

# %%
sinasc.IDADEMAE
# Out:
# 0        19
# 1        29
# 2        37
# 3        30
# 4        30
#          ..
# 27023    32
# 27024    19
# 27025    24
# 27026    21
# 27027    18
# Name: IDADEMAE, Length: 27028, dtype: int64

# %%
sinasc.PESO
# Out:
# 0        3685
# 1        3055
# 2        3460
# 3        2982
# 4        3310
#          ...
# 27023    2110
# 27024    3310
# 27025    3065
# 27026    2352
# 27027    4240
# Name: PESO, Length: 27028, dtype: int64

# %% [markdown]
# ####  1) Na base do SINASC do DataSUS, faça um boxplot da idade da mãe.

# %%
sinasc_idade_da_mae = sinasc['IDADEMAE']
plt.plot(sinasc_idade_da_mae)

# %% [markdown]
# ####  2) Faça um boxplot do peso do bebê

# %%
sinasc.PESO
# Out:
# 0        3685
# 1        3055
# 2        3460
# 3        2982
# 4        3310
#          ...
# 27023    2110
# 27024    3310
# 27025    3065
# 27026    2352
# 27027    4240
# Name: PESO, Length: 27028, dtype: int64

# %%
sinasc_peso_do_bebe = sinasc['PESO']
plt.plot(sinasc_peso_do_bebe)

# %% [markdown]
# ####  3) Faça um histograma da idade da mãe

# %%
plt.figure(figsize=(15, 5))
sns.countplot(data=sinasc, x=sinasc_idade_da_mae, palette='viridis')
# Out:
# C:\Users\Lucas\AppData\Local\Temp\ipykernel_9928\2474122513.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=sinasc, x=sinasc_idade_da_mae, palette='viridis')
# <Axes: xlabel='IDADEMAE', ylabel='count'>

# %% [markdown]
# #### 4) Faça um histograma do peso do bebê

# %%
plt.figure(figsize=(10, 15))
sns.countplot( data=sinasc,x=sinasc_peso_do_bebe, palette='viridis')
# Out:
# C:\Users\Lucas\AppData\Local\Temp\ipykernel_9928\3656795417.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot( data=sinasc,x=sinasc_peso_do_bebe, palette='viridis')
# <Axes: xlabel='PESO', ylabel='count'>
